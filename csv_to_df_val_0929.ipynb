# %%
import pandas as pd

# %%
# df column 선언
columns_Name_mAcc = ['UnixTime', 'UnixTime_sub', 'x1', 'y1', 'z1', 'x2', 'y2', 'z2', 'x3', 'y3', 'z3', 'x4', 'y4', 'z4', 'x5', 'y5', 'z5', 'x6', 'y6', 'z6', 'x7', 'y7', 'z7', 'x8', 'y8', 'z8', 'x9', 'y9', 'z9', 'x10', 'y10', 'z10']
columns_Name_mGyr = ['UnixTime', 'UnixTime_sub', 'x1', 'y1', 'z1', 'x2', 'y2', 'z2', 'x3', 'y3', 'z3', 'x4', 'y4', 'z4', 'x5', 'y5', 'z5', 'x6', 'y6', 'z6', 'x7', 'y7', 'z7', 'x8', 'y8', 'z8', 'x9', 'y9', 'z9', 'x10', 'y10', 'z10']
columns_Name_mPre = ['UnixTime', 'UnixTime_sub', 'val1']
columns_Name_mLi = ['UnixTime', 'UnixTime_sub', 'val1']

columns_Name_wAcc = ['UnixTime', 'UnixTime_sub', 'x1', 'y1', 'z1', 'x2', 'y2', 'z2', 'x3', 'y3', 'z3', 'x4', 'y4', 'z4', 'x5', 'y5', 'z5', 'x6', 'y6', 'z6', 'x7', 'y7', 'z7', 'x8', 'y8', 'z8', 'x9', 'y9', 'z9', 'x10', 'y10', 'z10']
columns_Name_wGyr = ['UnixTime', 'UnixTime_sub', 'x1', 'y1', 'z1', 'x2', 'y2', 'z2', 'x3', 'y3', 'z3', 'x4', 'y4', 'z4', 'x5', 'y5', 'z5', 'x6', 'y6', 'z6', 'x7', 'y7', 'z7', 'x8', 'y8', 'z8', 'x9', 'y9', 'z9', 'x10', 'y10', 'z10']
columns_Name_wPre = ['UnixTime', 'UnixTime_sub', 'val1']
columns_Name_wHR = ['UnixTime', 'UnixTime_sub', 'val1']

columns_Name_mAcc_11Hz = ['UnixTime', 'UnixTime_sub', 'x1', 'y1', 'z1', 'x2', 'y2', 'z2', 'x3', 'y3', 'z3', 'x4', 'y4', 'z4', 'x5', 'y5', 'z5', 'x6', 'y6', 'z6', 'x7', 'y7', 'z7', 'x8', 'y8', 'z8', 'x9', 'y9', 'z9', 'x10', 'y10', 'z10', 'x11', 'y11', 'z11']
columns_Name_mGyr_11Hz = ['UnixTime', 'UnixTime_sub', 'x1', 'y1', 'z1', 'x2', 'y2', 'z2', 'x3', 'y3', 'z3', 'x4', 'y4', 'z4', 'x5', 'y5', 'z5', 'x6', 'y6', 'z6', 'x7', 'y7', 'z7', 'x8', 'y8', 'z8', 'x9', 'y9', 'z9', 'x10', 'y10', 'z10', 'x11', 'y11', 'z11']
columns_Name_mPre_2Hz = ['UnixTime', 'UnixTime_sub', 'val1', 'val2']
columns_Name_mLi_2Hz = ['UnixTime', 'UnixTime_sub', 'val1', 'val2']

columns_Name_wAcc_11Hz = ['UnixTime', 'UnixTime_sub', 'x1', 'y1', 'z1', 'x2', 'y2', 'z2', 'x3', 'y3', 'z3', 'x4', 'y4', 'z4', 'x5', 'y5', 'z5', 'x6', 'y6', 'z6', 'x7', 'y7', 'z7', 'x8', 'y8', 'z8', 'x9', 'y9', 'z9', 'x10', 'y10', 'z10', 'x11', 'y11', 'z11']
columns_Name_wGyr_11Hz = ['UnixTime', 'UnixTime_sub', 'x1', 'y1', 'z1', 'x2', 'y2', 'z2', 'x3', 'y3', 'z3', 'x4', 'y4', 'z4', 'x5', 'y5', 'z5', 'x6', 'y6', 'z6', 'x7', 'y7', 'z7', 'x8', 'y8', 'z8', 'x9', 'y9', 'z9', 'x10', 'y10', 'z10', 'x11', 'y11', 'z11']
columns_Name_wPre_2Hz = ['UnixTime', 'UnixTime_sub', 'val1', 'val2']
columns_Name_wHR_2Hz = ['UnixTime', 'UnixTime_sub', 'val1', 'val2']

columns_Names = [columns_Name_mAcc, columns_Name_mGyr, columns_Name_mPre, columns_Name_mLi, columns_Name_wAcc, columns_Name_wGyr, columns_Name_wPre, columns_Name_wHR]
columns_Names_sub = [columns_Name_mAcc_11Hz, columns_Name_mGyr_11Hz, columns_Name_mPre_2Hz, columns_Name_mLi_2Hz, columns_Name_wAcc_11Hz, columns_Name_wGyr_11Hz, columns_Name_wPre_2Hz, columns_Name_wHR_2Hz]
# 센서 리스트 선언
sensors = ['mAcc', 'mGyr', 'mPre', 'mLi', 'wAcc', 'wGyr', 'wPre', 'wHR']

# %%
def data_Validation_1(df_data, data_name):

    if df_data is None:
        return print('\nThis is empty data\t' + data_name)

    len_df_data = len(df_data)

    min_data = int(df_data['UnixTime'].min())
    max_data = int(df_data['UnixTime'].max())

    df_data = df_data.astype('float')
    df_data = df_data.astype({'UnixTime':'int'})
    df_data = df_data.sort_values('UnixTime')
    df_data = df_data.reset_index(drop=True)

    print('')
    print('[' + data_name + ']')
    print('Start time: ', min_data)
    print('End time: ', max_data)
    print('Time interval: ', max_data - min_data)
    print('Number of instance: ', len_df_data)
    print('Number of duplicated data: ', df_data.duplicated().sum())
    print('Number of missing instance: ', max_data - min_data - len_df_data)

# %%
def data_Validation_2(df_data, data_name):

    if df_data is None:
        return print('\nThis is empty data\t' + data_name)

    len_df_data = len(df_data)

    min_data = df_data['UnixTime'].min()
    max_data = df_data['UnixTime'].max()

    df_data = df_data.astype('int')
    df_data = df_data.astype({'UnixTime':'int'})
    df_data = df_data.sort_values('UnixTime')
    df_data = df_data.reset_index(drop=True)

    return (len_df_data - df_data.duplicated().sum())

# %%
# csv 읽기, on_bad_lines='skip' 해줘야 함
import datetime
import os

sid = int(input("Input SID"))
start_Month = int(input("Input start month"))
start_Day = int(input("Input start day"))

start_Date = datetime.datetime(2022, start_Month, start_Day)

loop_Flag = True

for i in range(0, 60):

    if loop_Flag == True:

        all_Instance = 0

        for j in range(0, 8):

            date = start_Date.strftime("%m%d")

            csv_Folder_Root = "./val/S" + str(sid)
            val_Folder_Root = "./S" + str(sid)

            # txt_Root = "./val/S" + str(sid) + "/" + str(sid) + "_" + date + "_" + sensors[j] + ".txt"
            txt_Root = "./val/S" + str(sid) + "/" + str(sid) + "_" + date + ".txt"
            csv_Root = "./S" + str(sid) + "/" + str(sid) + "_" + date + "_" + sensors[j] + ".csv"

            # 디렉토리 만들기
            try:
                if not os.path.exists(csv_Folder_Root):
                    os.makedirs(csv_Folder_Root)
            except OSError:
                print('Error: Creating directory. ' + csv_Folder_Root)
                
            try:
                if not os.path.exists(val_Folder_Root):
                    os.makedirs(val_Folder_Root)
            except OSError:
                print('Error: Creating directory. ' + val_Folder_Root)
            
            try:    
                f = open(txt_Root, 'w')
                
    # Loop - Validation START

                df = pd.read_csv(csv_Root, on_bad_lines='skip')
                
                # UnixTime과 UnixTime_sub이 될 값만 선택하여 df를 재구성
                df = df.iloc[:, 0:2]
                df = df.dropna()
                df.columns = ['UnixTime', 'UnixTime_sub']

                # df.columns = columns_Names[j]

                # df 캐스팅
                df['UnixTime'] = df['UnixTime'].astype(int)
                df['UnixTime'] = df['UnixTime'].astype(str)
                df['UnixTime_sub'] = df['UnixTime_sub'].astype(int)
                df['UnixTime_sub'] = df['UnixTime_sub'].astype(str)

                # 6자리 맞추기
                df['UnixTime_sub'] = df['UnixTime_sub'].str.pad(width=6, side='left', fillchar='0')
                df['UnixTime'] = df['UnixTime'] + df['UnixTime_sub']
                df = df.drop('UnixTime_sub', axis = 1)

                # 이상치 제거
                index_drop = df[df['UnixTime'] == '16630000-4'].index
                df = df.drop(index_drop)
                # print(index_drop)

                # f.write(data_Validation_2(df, sensors[j]))
                val_result = data_Validation_2(df, sensors[j])

                print("[Number of instances] " + sensors[j] + "\t" +str(val_result))

                all_Instance = all_Instance + int(val_result)

                # f.close()

            except FileNotFoundError as e:
                print("\n[FileNotFoundError]\t" + csv_Root)
                loop_Flag = False
                break

            # except ValueError as e:
            #     print("ERROR, RETRY!" + sensors[j])
            #     print(e)

    # Loop - Validation END

            # print("[Number of all instances]: " + str(all_Instance))

            rate = round(float(all_Instance) / 691200.0 * 100.0, 1)

            f.write(str(rate))
            f.close()
        print("[Average daily collection rate]\t" + str(rate) + "%")

        rate = 0

        start_Date = start_Date + datetime.timedelta(days=1)

f.close()

print("\n[DONE]")
# Out:
# [Number of instances] mAcc	48329
# [Number of instances] mGyr	48327
# [Number of instances] mPre	48104
# [Number of instances] mLi	39426
# [Number of instances] wAcc	39947
# [Number of instances] wGyr	39946
# [Number of instances] wPre	41117
# [Number of instances] wHR	40977
# [Average daily collection rate]	50.1%
#
# [FileNotFoundError]	./S618/618_0923_mAcc.csv
# [Average daily collection rate]	0%
#
# [DONE]
